# %%
import os
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Inputs

# %%
os.listdir("../input/")
# Out:
# ['Addresses.csv',
#  'all_edges.csv',
#  'Entities.csv',
#  'Intermediaries.csv',
#  'Officers.csv']

# %%
entities = pd.read_csv('../input/Entities.csv')
addresses = pd.read_csv('../input/Addresses.csv')
intermediaries = pd.read_csv('../input/Intermediaries.csv')
officers = pd.read_csv('../input/Officers.csv')
edges = pd.read_csv('../input/all_edges.csv')
# Out:
# D:\Users\gdrtmh\AppData\Local\Continuum\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (1,2,5,6,9,10,11,12,13,15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# D:\Users\gdrtmh\AppData\Local\Continuum\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# D:\Users\gdrtmh\AppData\Local\Continuum\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (1,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# D:\Users\gdrtmh\AppData\Local\Continuum\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## Missing Data

# %%
# Check to see if there are any missing values in our data set
entities.isnull().any()
# Out:
# name                         True
# original_name                True
# former_name                  True
# jurisdiction                False
# jurisdiction_description    False
# company_type                 True
# address                      True
# internal_id                  True
# incorporation_date           True
# inactivation_date            True
# struck_off_date              True
# dorm_date                    True
# status                       True
# service_provider             True
# ibcRUC                       True
# country_codes                True
# countries                    True
# note                         True
# valid_until                 False
# node_id                     False
# sourceID                    False
# dtype: bool

# %%
pd.DataFrame([entities.columns.values, 
addresses.columns.values,
 intermediaries.columns.values, 
 officers.columns.values, 
 edges.columns.values])
# Out:
#         0              1            2              3   \
# 0     name  original_name  former_name   jurisdiction
# 1  address        icij_id  valid_until  country_codes
# 2     name    internal_id      address    valid_until
# 3     name        icij_id  valid_until  country_codes
# 4   node_1       rel_type       node_2       sourceID
#
#                          4             5         6            7   \
# 0  jurisdiction_description  company_type   address  internal_id
# 1                 countries       node_id  sourceID         note
# 2             country_codes     countries    status      node_id
# 3                 countries       node_id  sourceID         note
# 4               valid_until    start_date  end_date         None
#
#                    8                  9     ...            11      12  \
# 0  incorporation_date  inactivation_date    ...     dorm_date  status
# 1                None               None    ...          None    None
# 2            sourceID               note    ...          None    None
# 3                None               None    ...          None    None
# 4                None               None    ...          None    None
#
#                  13      14             15         16    17           18  \
# 0  service_provider  ibcRUC  country_codes  countries  note  valid_until
# 1              None    None           None       None  None         None
# 2              None    None           None       None  None         None
# 3              None    None           None       None  None         None
# 4              None    None           None       None  None         None
#
#         19        20
# 0  node_id  sourceID
# 1     None      None
# 2     None      None
# 3     None      None
# 4     None      None
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Entities

# %%
entities.head(3)
# Out:
#                                           name  \
# 0     TIANSHENG INDUSTRY AND TRADING CO., LTD.
# 1  NINGBO SUNRISE ENTERPRISES UNITED CO., LTD.
# 2                           HOTFOCUS CO., LTD.
#
#                                  original_name former_name jurisdiction  \
# 0     TIANSHENG INDUSTRY AND TRADING CO., LTD.         NaN          SAM
# 1  NINGBO SUNRISE ENTERPRISES UNITED CO., LTD.         NaN          SAM
# 2                           HOTFOCUS CO., LTD.         NaN          SAM
#
#   jurisdiction_description company_type  \
# 0                    Samoa          NaN
# 1                    Samoa          NaN
# 2                    Samoa          NaN
#
#                                              address  internal_id  \
# 0  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...    1001256.0
# 1  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...    1001263.0
# 2  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...    1000896.0
#
#   incorporation_date inactivation_date      ...       dorm_date     status  \
# 0        23-MAR-2006       18-FEB-2013      ...             NaN  Defaulted
# 1        27-MAR-2006       27-FEB-2014      ...             NaN  Defaulted
# 2        10-JAN-2006       15-FEB-2012      ...             NaN  Defaulted
#
#   service_provider ibcRUC country_codes  countries note  \
# 0  Mossack Fonseca  25221           HKG  Hong Kong  NaN
# 1  Mossack Fonseca  25249           HKG  Hong Kong  NaN
# 2  Mossack Fonseca  24138           HKG  Hong Kong  NaN
#
#                                       valid_until   node_id       sourceID
# 0  The Panama Papers data is current through 2015  10000001  Panama Papers
# 1  The Panama Papers data is current through 2015  10000002  Panama Papers
# 2  The Panama Papers data is current through 2015  10000003  Panama Papers
#
# [3 rows x 21 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

f, axarr = plt.subplots(2, 2, figsize=(12, 11))
f.subplots_adjust(hspace=0.75)
plt.suptitle('Cash-Stash Entity Breakdown', fontsize=18)

entities['sourceID'].value_counts().plot.bar(ax=axarr[0][0])
axarr[0][0].set_title("Data Source")

entities['service_provider'].value_counts(dropna=False).plot.bar(ax=axarr[0][1])
axarr[0][1].set_title("Money Manager")

entities['jurisdiction_description'].value_counts().head(10).plot.bar(ax=axarr[1][0])
axarr[1][0].set_title("Jurisdiction (n=10)")

entities['countries'].value_counts(dropna=False).head(10).plot.bar(ax=axarr[1][1])
axarr[1][1].set_title("Home Country (n=10)")

# %%
entities['DT.incorporation_dates'] = pd.to_datetime(entities.incorporation_date, format="%d-%b-%Y")
entities['DT.inactivation_dates']  = pd.to_datetime(entities.inactivation_date, format="%d-%b-%Y")

# %%
f, axarr = plt.subplots(1, 2, figsize=(12, 4))
f.subplots_adjust(hspace=0.75)

entities['DT.incorporation_dates'].dt.year.dropna().astype(int).value_counts().head(20).sort_index().plot.bar(
    ax=axarr[0]
)
axarr[0].set_title("Year of Incorporation")

(entities['DT.inactivation_dates'] - entities['DT.incorporation_dates']).dropna().map(lambda v: v.days).plot.hist(
    ax=axarr[1], bins=200
)
axarr[1].set_title("Fund Survival Time (Days)")
axarr[1].set_xlim([0, 15000])
pass

# %% [markdown]
# ### Intermediaries

# %%
intermediaries.head()
# Out:
#                          name internal_id  \
# 0     MICHAEL PAPAGEORGE, MR.       10001
# 1          CORFIDUCIA ANSTALT       10004
# 2               DAVID, RONALD       10014
# 3  DE  BOUTSELIS, JEAN-PIERRE       10015
# 4    THE LEVANT LAWYERS (TLL)       10029
#
#                                              address  \
# 0  MICHAEL PAPAGEORGE; MR. 106 NICHOLSON STREET B...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        valid_until country_codes  \
# 0  The Panama Papers  data is current through 2015           ZAF
# 1  The Panama Papers  data is current through 2015           LIE
# 2  The Panama Papers  data is current through 2015           MCO
# 3  The Panama Papers  data is current through 2015           BEL
# 4  The Panama Papers  data is current through 2015           LBN
#
#        countries     status   node_id       sourceID note
# 0   South Africa     ACTIVE  11000001  Panama Papers  NaN
# 1  Liechtenstein     ACTIVE  11000002  Panama Papers  NaN
# 2         Monaco  SUSPENDED  11000003  Panama Papers  NaN
# 3        Belgium  SUSPENDED  11000004  Panama Papers  NaN
# 4        Lebanon     ACTIVE  11000005  Panama Papers  NaN

# %%
f, axarr = plt.subplots(1, 2, figsize=(12, 4))
f.subplots_adjust(hspace=0.75)

intermediaries['countries'].value_counts().head(20).plot.bar(ax=axarr[0])
axarr[0].set_title("Data Source")

intermediaries['status'].value_counts().head(10).plot.pie(ax=axarr[1], startangle=90).legend(loc=3, fontsize=5)
axarr[1].set_title("Fund Survival Time (Days)")

# %%
intermediaries['status'].value_counts(normalize=True, dropna = False).head(10)*100
# Out:
# NaN                                   47.797493
# ACTIVE                                29.209579
# SUSPENDED                             19.671589
# UNRECOVERABLE ACCOUNTS                 1.580014
# INACTIVE                               1.116764
# PROSPECT                               0.372255
# CLIENT IN REPRESENTATIVE TERRITORY     0.095132
# DELINQUENT                             0.086859
# ACTIVE LEGAL                           0.057906
# SUSPENDED LEGAL                        0.012408
# Name: status, dtype: float64

# %%
PopIntermediatries_Countries=list(intermediaries['countries'].value_counts().head(20).index)
PopIntermediatries_Status=list(['ACTIVE', 'SUSPENDED'])

# %%
intermediaries[(intermediaries['status'].isin(PopIntermediatries_Status))&(intermediaries['countries'].isin(PopIntermediatries_Countries))].groupby(['countries', 'status']).size().unstack().plot(kind='bar', stacked=False)
plt.title("Top 20 Countries with respect to the popularity of accounts")

# %% [markdown]
# ### Addresses

# %%
addresses.head()
# Out:
#                                              address  \
# 0       -\t27 ROSEWOOD DRIVE #16-19 SINGAPORE 737920
# 1            "Almaly Village" v.5, Almaty Kazakhstan
# 2  "Cantonia" South Road St Georges Hill Weybridg...
# 3  "CAY-OS" NEW ROAD; ST.SAMPSON; GUERNSEY; CHANN...
# 4  "Chirag" Plot No 652; Mwamba Road; Kizingo; Mo...
#
#                             icij_id  \
# 0  6991059DFFB057DF310B9BF31CC4A0E6
# 1  C65A269424AA1A8BBAC416FA30150938
# 2  240EE44DFB70AF775E6CD02AF8CB889B
# 3  340C6D3D2FC60AE58C53BB3618129C43
# 4  6DBCD74F5AAB63EABC166885CE8CD7CD
#
#                                        valid_until country_codes  \
# 0  The Panama Papers  data is current through 2015           SGP
# 1  The Panama Papers  data is current through 2015           KAZ
# 2  The Panama Papers  data is current through 2015           GBR
# 3  The Panama Papers  data is current through 2015           GGY
# 4  The Panama Papers  data is current through 2015           KEN
#
#         countries   node_id       sourceID note
# 0       Singapore  14000001  Panama Papers  NaN
# 1      Kazakhstan  14000002  Panama Papers  NaN
# 2  United Kingdom  14000003  Panama Papers  NaN
# 3        Guernsey  14000004  Panama Papers  NaN
# 4           Kenya  14000005  Panama Papers  NaN

# %%
addresses['countries'].value_counts().head(40).plot.bar(
    title='Addresses Mentioned by Country (n=40)', figsize=(12, 6)
)

# %%
### officers

# %%
officers.head()
# Out:
#                    name                           icij_id  \
# 0            KIM SOO IN  E72326DEA50F1A9C2876E112AAEB42BC
# 1             Tian Yuan  58287E0FD37852000D9D5AB8B27A2581
# 2  GREGORY JOHN SOLOMON  F476011509FD5C2EF98E9B1D74913CCE
# 3        MATSUDA MASUMI  974F420B2324A23EAF46F20E178AF52C
# 4           HO THUY NGA  06A0FC92656D09F63D966FE7BD076A45
#
#                                       valid_until country_codes    countries  \
# 0  The Panama Papers data is current through 2015           KOR  South Korea
# 1  The Panama Papers data is current through 2015           CHN        China
# 2  The Panama Papers data is current through 2015           AUS    Australia
# 3  The Panama Papers data is current through 2015           JPN        Japan
# 4  The Panama Papers data is current through 2015           VNM     Viet Nam
#
#     node_id       sourceID note
# 0  12000001  Panama Papers  NaN
# 1  12000002  Panama Papers  NaN
# 2  12000003  Panama Papers  NaN
# 3  12000004  Panama Papers  NaN
# 4  12000005  Panama Papers  NaN

# %%
officers['countries'].value_counts(dropna=False).head(40).plot.bar(
    title='Country of Origin of Officers (n=40)', figsize=(12, 6)
)

# %% [markdown]
# ### edges

# %%
edges.head()
# Out:
#      node_1         rel_type    node_2       sourceID  \
# 0  11000001  intermediary of  10208879  Panama Papers
# 1  11000001  intermediary of  10198662  Panama Papers
# 2  11000001  intermediary of  10159927  Panama Papers
# 3  11000001  intermediary of  10165779  Panama Papers
# 4  11000001  intermediary of  10152967  Panama Papers
#
#                                       valid_until start_date end_date
# 0  The Panama Papers data is current through 2015        NaN      NaN
# 1  The Panama Papers data is current through 2015        NaN      NaN
# 2  The Panama Papers data is current through 2015        NaN      NaN
# 3  The Panama Papers data is current through 2015        NaN      NaN
# 4  The Panama Papers data is current through 2015        NaN      NaN

# %%
edges['sourceID'].value_counts().head(10).plot.pie(startangle=90, shadow= True).legend(loc=3, fontsize=5)
axarr[1].set_title("Fund Survival Time (Days)")

# %% [markdown]
# # Joining Data
# attemps to join the merge the data

# %%
PopEdgess_rel=list(edges['rel_type'].value_counts().head(40).index)
# edges.rel_type.value_counts().head(40)

# %%
relationship2code = pd.DataFrame(PopEdgess_rel, columns=['relationship'])
relationship2code = relationship2code.assign(code=pd.Series([1] * len(PopEdgess_rel)).values)

Identical_rel_list=list(['similar name and address as', 'same name as', 'same company as',
                         'same name and registration date as', 'same address as', 'related entity',
                         'entity similar to','probably same officer as'])

relationship2code.loc[df1['relationship'].isin(Identical_rel_list),'code']=0

relationship2code
# Out:
#                           relationship  code
# 0                      intermediary of     1
# 1                       shareholder of     1
# 2                   registered address     1
# 3                          director of     1
# 4          similar name and address as     0
# 5               records & registers of     1
# 6                         same name as     0
# 7                             director     1
# 8                       beneficiary of     1
# 9                      same company as     0
# 10                        secretary of     1
# 11                           secretary     1
# 12  same name and registration date as     0
# 13                director / president     1
# 14                director / secretary     1
# 15                 beneficial owner of     1
# 16                 trustee of trust of     1
# 17                           president     1
# 18                    trust settlor of     1
# 19    authorised person / signatory of     1
# 20                        protector of     1
# 21              Nominee Shareholder of     1
# 22               president / secretary     1
# 23                     same address as     0
# 24                             officer     1
# 25                 assistant secretary     1
# 26                      related entity     0
# 27              assistant secretary of     1
# 28               alternate director of     1
# 29              co-trustee of trust of     1
# 30                          officer of     1
# 31                resident director of     1
# 32                      vice president     1
# 33                          auditor of     1
# 34                   entity similar to     0
# 35              correspondent addr. of     1
# 36                authorized signatory     1
# 37            probably same officer as     0
# 38                           treasurer     1
# 39           vice president / director     1

# %%
edges.shape
# Out:
# (1535552, 7)

# %%
officers.shape
# Out:
# (370854, 8)

# %%
pd.merge(officers, edges[['node_1','rel_type']],left_on='node_id', right_on='node_1', how='inner').shape
# Out:
# (926144, 10)

# %%
pd.merge(officers, edges,left_on='node_id', right_on='node_2', how='inner').shape
# Out:
# (68223, 15)

# %%
pd.merge(officers, edges[['node_1','rel_type']],left_on='node_id', right_on='node_1', how='inner')
# Out:
#                                      name                           icij_id  \
# 0                              KIM SOO IN  E72326DEA50F1A9C2876E112AAEB42BC
# 1                              KIM SOO IN  E72326DEA50F1A9C2876E112AAEB42BC
# 2                               Tian Yuan  58287E0FD37852000D9D5AB8B27A2581
# 3                               Tian Yuan  58287E0FD37852000D9D5AB8B27A2581
# 4                    GREGORY JOHN SOLOMON  F476011509FD5C2EF98E9B1D74913CCE
# 5                    GREGORY JOHN SOLOMON  F476011509FD5C2EF98E9B1D74913CCE
# 6                          MATSUDA MASUMI  974F420B2324A23EAF46F20E178AF52C
# 7                          MATSUDA MASUMI  974F420B2324A23EAF46F20E178AF52C
# 8                             HO THUY NGA  06A0FC92656D09F63D966FE7BD076A45
# 9                             HO THUY NGA  06A0FC92656D09F63D966FE7BD076A45
# 10                         RACHMAT ARIFIN  14BCB3A8F783A319511E6C5EF5F4BB30
# 11                         RACHMAT ARIFIN  14BCB3A8F783A319511E6C5EF5F4BB30
# 12                            TAN SUN-HUA  C3912EA62746F395A64FB216BE464F61
# 13                            TAN SUN-HUA  C3912EA62746F395A64FB216BE464F61
# 14          Ou Yang Yet-Sing and Chang Ko  DB896EE47F60BB1B2E9EA9C10ACBFCD7
# 15          Ou Yang Yet-Sing and Chang Ko  DB896EE47F60BB1B2E9EA9C10ACBFCD7
# 16      Wu Chi-Ping and Wu Chou Tsan-Ting  1B92FDDD451DA8DCA9CD36B0AF797411
# 17      Wu Chi-Ping and Wu Chou Tsan-Ting  1B92FDDD451DA8DCA9CD36B0AF797411
# 18                          ZHONG LI MING  0AE47CB442426F2ACF73E42BFA6657FA
# 19                          ZHONG LI MING  0AE47CB442426F2ACF73E42BFA6657FA
# 20                          ZHONG LI MING  0AE47CB442426F2ACF73E42BFA6657FA
# 21                               LIN PING  BB8842DD315BB503CCCE1D3B23575A14
# 22                               LIN PING  BB8842DD315BB503CCCE1D3B23575A14
# 23                               LIN PING  BB8842DD315BB503CCCE1D3B23575A14
# 24                     BOSHEN LTD./135-77  5F64E7218A4743275D1098ED6F7C8221
# 25                     BOSHEN LTD./133-58  B08B58F2381272DDE80A02220EDF938A
# 26                     BOSHEN LTD./132-50  69D406C865AA5A91B290E6EB49A9C430
# 2           shareholder of
# 3       registered address
# 4           shareholder of
# 5       registered address
# 6           shareholder of
# 7       registered address
# 8           shareholder of
# 9       registered address
# 10          shareholder of
# 11      registered address
# 12          shareholder of
# 13      registered address
# 14          shareholder of
# 15      registered address
# 16          shareholder of
# 17      registered address
# 18          shareholder of
# 19          shareholder of
# 20      registered address
# 21          shareholder of
# 22          shareholder of
# 23      registered address
# 24          shareholder of
# 25          shareholder of
# 26          shareholder of
# 27          shareholder of
# 28          shareholder of
# 29          shareholder of
# ...                    ...
# 926114  registered address
# 926115      beneficiary of
# 926116  registered address
# 926117      beneficiary of
# 926118      beneficiary of
# 926119      beneficiary of
# 926120  registered address
# 926121      beneficiary of
# 926122      beneficiary of
# 926123  registered address
# 926124      beneficiary of
# 926125  registered address
# 926126      beneficiary of
# 926127      beneficiary of
# 926128  registered address
# 926129      beneficiary of
# 926130  registered address
# 926131      beneficiary of
# 926132  registered address
# 926133      beneficiary of
# 926134      beneficiary of
# 926135      beneficiary of
# 926136      beneficiary of
# 926137      beneficiary of
# 926138      beneficiary of
# 926139  registered address
# 926140      beneficiary of
# 926141  registered address
# 926142      beneficiary of
# 926143  registered address
#
# [926144 rows x 10 columns]

# %%
pd.merge(officers, edges[['node_2','rel_type']],left_on='node_id', right_on='node_2', how='inner')
# Out:
#                                                  name  \
# 0                              Noble Nominess Limited
# 1                                PILMAN HOLDINGS LTD.
# 2                             OMNI CAPITAL ASSETS LTD
# 3                            OMNI Capital Assets Ltd.
# 4                                            SMS LTD.
# 5                                     Suliman Dockrat
# 6                                     SULIMAN DOCKRAT
# 7                            M.Z. HASSAM FAMILY TRUST
# 8                                         SAFRAN INC.
# 9                                       CALCORE CORP.
# 10                       George Hill Nominees Limited
# 11                               UBS NOMINEES LIMITED
# 12                                    Suliman Dockrat
# 13                                    Suliman Dockrat
# 14                                      KELLDYNE LTD.
# 15                                      KELLDYNE LTD.
# 16                                      DEXFORD CORP.
# 17                    CORPORATE CONSULTING GROUP INC.
# 18                    Christine Cornelia van den Berg
# 19                             ALGISA INVESTMENT INC.
# 20                                  GROUPWISE LIMITED
# 21                                   Robert Alexander
# 22                                   Robert Alexander
# 23                                     JURGEN MOSSACK
# 24      GUANGZHOU CONSTRUCTION & DEVELOPMENT HOLDINGS
# 25                        PAULO SERGIO DA SILVA GIRIO
# 26                                       TREX LIMITED
# 27     GUANGZHOUR CONSTRUCTION & DEVELOPMENT HOLDINGS
# 28     GUANGZHOUR CONSTRUCTION & DEVELOPMENT HOLDINGS
# 29                           MACKFIELD INDUSTRIES LTD
# ...                                               ...
# 68193                              PERFECT PITCH LTD.
# 68194                                  Mr. Okan YÜCEL
# 68195                                   WONG MAN SUEN
# 68196                              Andrew John Baxter
# 68197                                    WANG ZILIANG
# 68198                                     Zou Huifang
# 68199                                  YEUNG CHI SHUN
# 68200                   Erkin Inggriani Tedjokoesoemo
# 68201                                   JOSEPH ZAMMIT
# 68202                 CARLOS ALBERTO MARQUES CARDETAS
# 68196               Australia  13003220  Panama Papers  NaN  13003220
# 68197                   China  13003223  Panama Papers  NaN  13003223
# 68198                   China  13003226  Panama Papers  NaN  13003226
# 68199               Hong Kong  13003227  Panama Papers  NaN  13003227
# 68200               Singapore  13003228  Panama Papers  NaN  13003228
# 68201                   Malta  13003229  Panama Papers  NaN  13003229
# 68202                  Brazil  13003231  Panama Papers  NaN  13003231
# 68203                  France  13003232  Panama Papers  NaN  13003232
# 68204               Argentina  13003233  Panama Papers  NaN  13003233
# 68205                   China  13003235  Panama Papers  NaN  13003235
# 68206                  Mexico  13003237  Panama Papers  NaN  13003237
# 68207                  Mexico  13003237  Panama Papers  NaN  13003237
# 68208                   China  13003239  Panama Papers  NaN  13003239
# 68209               Hong Kong  13001604  Panama Papers  NaN  13001604
# 68210               Hong Kong  13001604  Panama Papers  NaN  13001604
# 68211               Hong Kong  13001604  Panama Papers  NaN  13001604
# 68212                   China  13001606  Panama Papers  NaN  13001606
# 68213                   Japan  13001608  Panama Papers  NaN  13001608
# 68214                   China  13001609  Panama Papers  NaN  13001609
# 68215                    Peru  13001610  Panama Papers  NaN  13001610
# 68216          United Kingdom  13001611  Panama Papers  NaN  13001611
# 68217                   China  13001615  Panama Papers  NaN  13001615
# 68218                   China  13001620  Panama Papers  NaN  13001620
# 68219                   Macao  13001623  Panama Papers  NaN  13001623
# 68220               Venezuela  13001624  Panama Papers  NaN  13001624
# 68221               Hong Kong  13001626  Panama Papers  NaN  13001626
# 68222                   China  13001632  Panama Papers  NaN  13001632
#
#                           rel_type
# 0      similar name and address as
# 1      similar name and address as
# 2      similar name and address as
# 3      similar name and address as
# 4                     same name as
# 5                     same name as
# 6                     same name as
# 7      similar name and address as
# 8      similar name and address as
# 9      similar name and address as
# 10     similar name and address as
# 11                    same name as
# 12     similar name and address as
# 13                    same name as
# 14     similar name and address as
# 15     similar name and address as
# 16     similar name and address as
# 17     similar name and address as
# 18     similar name and address as
# 19     similar name and address as
# 20     similar name and address as
# 21                    same name as
# 22        probably same officer as
# 23                    same name as
# 24     similar name and address as
# 25                    same name as
# 26                    same name as
# 27     similar name and address as
# 28     similar name and address as
# 29     similar name and address as
# ...                            ...
# 68193  similar name and address as
# 68194  similar name and address as
# 68195  similar name and address as
# 68196  similar name and address as
# 68197  similar name and address as
# 68198  similar name and address as
# 68199  similar name and address as
# 68200  similar name and address as
# 68201  similar name and address as
# 68202  similar name and address as
# 68203  similar name and address as
# 68204  similar name and address as
# 68205  similar name and address as
# 68206  similar name and address as
# 68207  similar name and address as
# 68208  similar name and address as
# 68209  similar name and address as
# 68210  similar name and address as
# 68211  similar name and address as
# 68212  similar name and address as
# 68213  similar name and address as
# 68214  similar name and address as
# 68215  similar name and address as
# 68216  similar name and address as
# 68217  similar name and address as
# 68218  similar name and address as
# 68219  similar name and address as
# 68220  similar name and address as
# 68221  similar name and address as
# 68222  similar name and address as
#
# [68223 rows x 10 columns]

# %%
officers.shape
# Out:
# (370854, 8)
